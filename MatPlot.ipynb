# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt


music_data = pd.read_csv("graph.csv")
input_set = music_data.drop(columns=["point"])
output_set = music_data["point"]
model = DecisionTreeClassifier()
model.fit(input_set.values, output_set)
x = model.predict([[25, 36]]).tolist()
y = model.predict([[25, 7]]).tolist()
z = model.predict([[26, 10]]).tolist()
x.append(4)
y.append(10)
z.append(3)
plt.style.use("seaborn")
plt.plot(x,y)
plt.plot(x,z)
plt.legend(["X", "Y"])
plt.title("Test PyPlot")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.show()
